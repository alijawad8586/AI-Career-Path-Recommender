# %% [markdown]
# <a href="https://colab.research.google.com/github/alijawad8586/AI-Career-Path-Recommender/blob/main/LECL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-google-genai langchain-core
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 2.6 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyCEotfTTh9EO4YtOtqxFopXAKR3oXDw5LY"

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

# %%
prompt = PromptTemplate(

    template="What is a good name for a company that makes {product}?",
)

# %%
 output_parser=StrOutputParser(),

# %%
prompt = PromptTemplate.from_template(
    "Explain this topic in simple English and Roman Urdu: {topic}"
)

parser = StrOutputParser()

chain = prompt | model | parser

# %%
result = chain.invoke({"topic": "LCEL in LangChain"})
print(result)
# Out:
# Let's break down LCEL in LangChain in simple terms.
#
# ---
#
# ## LCEL in LangChain (Simple English)
#
# Imagine you're building a complex recipe. You have different steps: preparing ingredients, mixing them, baking, and finally decorating. Each step takes the output of the previous step as its input.
#
# **LCEL (LangChain Expression Language)** is like a special language or toolkit within LangChain that helps you connect these different "ingredients" (components) of your AI application smoothly and efficiently.
#
# **What is it?**
# LCEL stands for **LangChain Expression Language**. It's a new, more powerful, and easier way to build chains of operations in LangChain.
#
# **Why was it created?**
# ...
